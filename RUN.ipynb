# %% [markdown]
# # Use a larger fraction of the browser window

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:98% !important; }</style>"))
# Out:
# <style>.container { width:98% !important; }</style>

# %% [markdown]
# # Spectroscopic HRDs

# %%
# %matplotlib ipympl
what_plot = 'hrd'
figsize=(12, 12)
# %run paper2_figures.ipynb
# Out:
# WARNING: UnitsWarning: '[d]' did not parse as cds unit: Invalid character at col 0 [astropy.units.core]
# paper2_figures.ipynb:151: RuntimeWarning: divide by zero encountered in log10
#   "    loglis_lmc, ___ = compute_logli(loggs_lmc, logtes_lmc)\n",
# <img src="data:image/png;base64,..." width="1200">
# <img src="data:image/png;base64,..." width="1200">
# paper2_figures.ipynb:327: UserWarning: FixedFormatter should only be used together with FixedLocator
#   "        labels.append(desommaMW_hull)\n",

# %% [markdown]
# # Other figures

# %%
# %matplotlib ipympl
what_plot = 'figs'
figsize = (12, 12)
# %run paper2_figures.ipynb
# Out:
# WARNING: UnitsWarning: '[d]' did not parse as cds unit: Invalid character at col 0 [astropy.units.core]
# paper2_figures.ipynb:151: RuntimeWarning: divide by zero encountered in log10
#   "    loglis_lmc, ___ = compute_logli(loggs_lmc, logtes_lmc)\n",
# <img src="data:image/png;base64,..." width="1200">
# <img src="data:image/png;base64,..." width="1200">
# <img src="data:image/png;base64,..." width="1200">
# <img src="data:image/png;base64,..." width="1200">
