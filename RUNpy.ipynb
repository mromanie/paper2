# %%
# %matplotlib ipympl
# %run paper2_figures.py 'figs'
# Out:
# WARNING: UnitsWarning: '[d]' did not parse as cds unit: Invalid character at col 0 [astropy.units.core]
# /home/jovyan/paper2_figures.py:151: RuntimeWarning: divide by zero encountered in log10
#   loggs_riess = p1.tab2arr(tab, 'Logg')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
